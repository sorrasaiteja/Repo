# %%
import pandas as pd,numpy as np
import matplotlib.pyplot as plt
import random
import seaborn as sns
from scipy.stats import norm

# %%
# ?plt.hist

# %%
X= np.random.uniform(0,1,100000)
X
# Out:
# array([0.61022428, 0.49443667, 0.71395439, ..., 0.48336994, 0.59629611,
#        0.74327435])

# %%
plt.hist(X, bins = 100);

# %%
X = np.random.poisson(10, 1000000)

# %%
plt.hist(X, bins = 100);

# %%
mu = 10
sigma = 5
X = np.random.normal(mu,sigma,100000000)

# %%
plt.hist(X, bins = 1000);

# %%
np.exp(1)
# Out:
# 2.718281828459045

# %%
listn = np.arange(-20,40,0.001)
listn
# Out:
# array([-20.   , -19.999, -19.998, ...,  39.997,  39.998,  39.999])

# %%
(2*np.pi)**0.5
# Out:
# 2.5066282746310002

# %%
densitylistn = (1/(((2*np.pi)**0.5)*sigma))*np.exp(-0.5*((listn - mu)/sigma)**2)
densitylistn
# Out:
# array([1.21517657e-09, 1.21663563e-09, 1.21809640e-09, ...,
#        1.21955887e-09, 1.21809640e-09, 1.21663563e-09])

# %%
densitylistn2 = norm.pdf(listn,mu, sigma)
densitylistn2
# Out:
# array([1.21517657e-09, 1.21663563e-09, 1.21809640e-09, ...,
#        1.21955887e-09, 1.21809640e-09, 1.21663563e-09])

# %%
plt.scatter(listn,densitylistn, s =0.01, c = 'blue');
plt.scatter(listn,densitylistn2, s =0.1, c = 'red');
plt.hist(X, bins = 1000, density = True, color = 'black');

# %%
# ?plt.scatter

# %%
plt.hist(X, bins = 1000, density = True);

# %%
from scipy.stats import norm
# ?norm.cdf

# %%
# ?norm.pdf

# %%
norm.cdf(20,10,5)-norm.cdf(0,10,5)
# Out:
# 0.9544997361036416

# %%
norm.cdf(200,100,50)-norm.cdf(0,100,50)
# Out:
# 0.9544997361036416

# %%
X = np.random.binomial(100,0.3,50)
X
# Out:
# array([31, 30, 36, 26, 25, 38, 28, 37, 23, 35, 29, 27, 30, 32, 28, 28, 25,
#        27, 21, 36, 31, 42, 33, 25, 30, 30, 20, 31, 24, 27, 24, 32, 36, 22,
#        36, 27, 24, 29, 25, 33, 26, 22, 34, 37, 29, 21, 30, 38, 30, 28])

# %%
Xbar = sum(X)/len(X)
Xbar
# Out:
# 29.36

# %%
X= np.random.uniform(0,1,1000000)
Y = np.random.uniform(0,1,1000000)
Z = X+Y

# %%
plt.hist(Z, bins = 100);
